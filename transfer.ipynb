# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras.optimizers import AdamW

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
train_dir = '/content/gdrive/MyDrive/final_polar_class/transfer/dataset_undersampled/train'
validation_dir = '/content/gdrive/MyDrive/final_polar_class/transfer/dataset_undersampled/val'
# test_dir = '/home/oleksandr/astro/prg/galfit_test/polar_classifier/pre/dataset/test'
BATCH_SIZE = 4
IMG_SIZE = [256, 256]

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)

validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
# Out:
# Found 100 files belonging to 2 classes.
# Found 50 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names


plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(4):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
model = tf.keras.models.load_model('/content/gdrive/MyDrive/final_polar_class/pre_train/model_pre.keras')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     795         try:
# --> 796             mod = importlib.import_module(module)
#     797         except ModuleNotFoundError:
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ...

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_resnet_v2 (Funct  (None, 1536)              54336736
#  ional)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
#  dense_1 (Dense)             (None, 1)                 513
#
# ...
# Total params: 55124193 (210.28 MB)
# Trainable params: 787457 (3.00 MB)
# Non-trainable params: 54336736 (207.28 MB)
# _________________________________________________________________

# %%
model.pop()
model.pop()

# %%
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_resnet_v2 (Funct  (None, 1536)              54336736
#  ional)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_2 (Dense)             (None, 512)               786944
#
#  dense_3 (Dense)             (None, 1)                 513
#
# ...
# Total params: 55124193 (210.28 MB)
# Trainable params: 787457 (3.00 MB)
# Non-trainable params: 54336736 (207.28 MB)
# _________________________________________________________________

# %%
model.layers[0].trainable = False

# %%
model.compile(optimizer = AdamW(learning_rate = 0.001, weight_decay = 0.4), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = 25
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-58cde495afa8> in <cell line: 1>()
# ----> 1 history = model.fit(
#       2     train_dataset,
#       3     validation_data = validation_dataset,
#       4     epochs = 25
#       5 )
#
# NameError: name 'model' is not defined

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save('/content/gdrive/MyDrive/final_polar_class/trained_model_adamW.keras')
